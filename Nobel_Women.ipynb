# %% [markdown]
# <a href="https://colab.research.google.com/github/CommunityRADvocate/nobel_winners/blob/main/Nobel_Women.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nobel Women
# ## An analysis of gender disparities in Nobel Prize awards from 1901-2019

# %% [markdown]
# ### About the data
# This data comes from Mariana Boger Netto (mbogernetto on Kaggle).
# [Link to data](https://www.kaggle.com/datasets/mbogernetto/women-in-nobel-prize-19012019)

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read in csv files from GitHub
all = pd.read_csv('https://raw.githubusercontent.com/CommunityRADvocate/nobel-women/main/data/nobel_prize_awarded_1901_2019.csv')
country = pd.read_csv('https://raw.githubusercontent.com/CommunityRADvocate/nobel-women/main/data/nobel_prize_awarded_country_details_1901_2019.csv')
women = pd.read_csv('https://raw.githubusercontent.com/CommunityRADvocate/nobel-women/main/data/nobel_prize_awarded_women_details_1901_2019.csv')

# %%
# get just countries and the categories they've been awarded for
country.groupby('Country').head()
# Out:
#                    Name  Year                      Country  \
# 0       14th Dalai Lama  1989                        Tibet
# 1     A. Michael Spence  2001                United States
# 2             Aage Bohr  1975                      Denmark
# 3     Aaron Ciechanover  2004                       Israel
# 4            Aaron Klug  1982                    Lithuania
# ...                 ...   ...                          ...
# 1083    Wangari Maathai  2004                        Kenya
# 1126       Wole Soyinka  1986                      Nigeria
# 1131      Yasser Arafat  1994                    Palestine
# 1137        Yuan T. Lee  1986  Taiwan (China, Republic of)
# 1140     Zhores Alferov  2000                      Belarus
#
#                         Countries    Category Gender                 Details
# 0                           Tibet       Peace    Man           born in Tibet
# 1                   United States   Economics    Man                     NaN
# ...

# %%
# testing github changes
